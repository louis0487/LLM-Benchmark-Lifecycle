# %% [markdown]
# # The Lifecycle and Clustering of LLM Benchmarks – A Data Driven Analysis

# %%
from IPython.display import Image, display
import os
LOC = os.devnull

# %% [markdown]
# ## A Brief History of Benchmarks

# %%
# !python src/plot_frontier_overlay.py > {LOC}
display(Image("results/frontier_overlay_logistic.png"))

# %% [markdown]
# ## MMLU Saturation

# %%
# !python src/mmlu_and_cluster_result.py   > {LOC}
display(Image("results/MMLU_lifecycle.png"))

# %% [markdown]
# ## Lifecycle of Benchmarks - Quadrant Analysis

# %%
# !python src/plot_benchmark_quadrant.py > {LOC}
display(Image("results/benchmark_quadrant.png"))

# %% [markdown]
# ## Correlation Analysis

# %%
# !python src/plot_benchmark_correlations.py  > {LOC}
display(Image("results/benchmark_correlation_heatmap.png"))

# %% [markdown]
# ## Clustering Analysis

# %%
display(Image("results/clustering_analysis.png"))

# %% [markdown]
# ## Saturation Analysis

# %%
# !python src/frontier_vs_saturated_comparison2.py  > {LOC}
display(Image("results/Focused_Benchmark_Analysis.png"))
